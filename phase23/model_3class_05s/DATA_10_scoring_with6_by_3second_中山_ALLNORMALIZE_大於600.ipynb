# %% [markdown]
# 從DATA_10/x_10_600.csv 找出前10駕駛超過600秒的屢次，各個欄位的平均值、標準差，給未來SAX轉換中的標準化使用。
#
# 從data_中山_bydriver/ 各個駕駛的屢次  找出大於600的X值，進行處理：
#     1. 儲存原始x
#     2. data_10_600
#
# 製作XY、進行label 切分

# %%
#複製檔案
import pandas as pd
import time
import os
import pickle
import SCORE
from shutil import copyfile


start = time.time()

Bdriverid=[31932651,31931745,31929871,31932404,31902662,
           31932370,31928725,31932602,31931992,31902118]    
for driver in Bdriverid:
    print('正在執行駕駛: ', driver ,'...')
#     pickle_list = glob.glob(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/{driver}/*.pickle')#回傳檔案的路近
    pickle_list = os.listdir(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/{driver}/') #回傳檔案名+副檔名
    print('本駕駛有幾趟旅次: ', len(pickle_list))
    
    _count=0 # 計本駕駛超過600的次數
    for p in pickle_list:
        print('旅次名稱: ', p)
        file_name = p.split(".")[0] #分開檔名與副檔名
        with open (f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/{driver}/{p}', 'rb') as f:
            d=pickle.load(f)
        print('本旅次有幾筆: ', len(d['time_data']))
        # 每旅次抓出time_data
        if len(d['time_data'])>600 :
        
            #新增每個旅次的資料夾、並且複製pickle檔案
            os.mkdir(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}")
            copyfile(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/{driver}/{p}',
                     f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/{p}")
# Out:
# 正在執行駕駛:  31932651 ...
# 本駕駛有幾趟旅次:  234
# 旅次名稱:  2020-09-06_77.pickle
# 本旅次有幾筆:  367
# 旅次名稱:  2020-10-22_79.pickle
# 本旅次有幾筆:  339
# 旅次名稱:  2020-09-29_80.pickle
# 本旅次有幾筆:  363
# 旅次名稱:  2020-09-22_92.pickle
# 本旅次有幾筆:  356
# 旅次名稱:  2020-09-19_64.pickle
# 本旅次有幾筆:  1826
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-19-cdef0db25854> in <module>
#      31
#      32             #新增每個旅次的資料夾、並且複製pickle檔案
# ---> 33             os.mkdir(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}")
#      34             copyfile(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/{driver}/{p}',
#      35                      f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/{p}")
#
# FileExistsError: [Errno 17] File exists: '/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/31932651/2020-09-19_64'

# %% [markdown]
# # 先組成全部X的csv，為了以後取得各col的mean std使用
# ## 得到X_all.scv

# %%
start = time.time()


df_x = pd.DataFrame(columns=['_time', 'x', 'y','z','yaw','roll','pitch','car_id','journey_id'] )
df_y = pd.DataFrame(columns=['score_3s_all'])
df_count=0
X=np.empty(shape=(0,3,6))

for driver in Bdriverid:
    print('正在執行駕駛: ', driver ,'...')
#     pickle_list = glob.glob(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/{driver}/*.pickle')#回傳檔案的路近
    pickle_list = os.listdir(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/') #回傳檔案名+副檔名
    print('本駕駛有幾趟旅次: ', len(pickle_list))
    
    _count=0 # 計本駕駛超過600的次數
    for p in pickle_list:
        print('旅次名稱: ', p)
        file_name = p.split(".")[0] #分開檔名與副檔名
        with open (f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{p}', 'rb') as f:
            d=pickle.load(f)
        print('本旅次有幾筆: ', len(d['time_data']))
        # 抓出time_data
        if len(d['time_data'])>600:
            df_t = pd.DataFrame(d['time_data'])
#             df_s = pd.DataFrame(d['score_3s_all'],columns=['score_3s_all'])
            df_t['journey_id']=file_name

            df_x=df_x.append(df_t) #儲存原始的timedata
#             df_y=df_y.append(df_s) #儲存
            _count+=1
            df_count+=1
        # 抓出score_3s_all
    print(f'本駕駛有{_count}筆的資料 .')
    print('\n')
print('---------------------------------------')
print(f'總共有{df_count}筆超過600的資料.')
print(f'總共有{len(df_x)}筆資料x')
# print(f'總共有{len(df_x)}筆資料x, 總共有{len(df_y)}筆資料y ........')
# print(f'總共有{len(X)}筆切割過的資料X, 總共有{len(df_y)}筆資料y ........')

end = time.time()
print(start, end)
print("執行時間：%f 秒" % (end - start))

df_x.to_csv('DATA_All/X_all.csv', index=False)
# Out:
# 正在執行駕駛:  31932651 ...
# 本駕駛有幾趟旅次:  234
# 旅次名稱:  2020-09-06_77.pickle
# 本旅次有幾筆:  367
# 旅次名稱:  2020-10-22_79.pickle
# 本旅次有幾筆:  339
# 旅次名稱:  2020-09-29_80.pickle
# 本旅次有幾筆:  363
# 旅次名稱:  2020-09-22_92.pickle
# 本旅次有幾筆:  356
# 旅次名稱:  2020-09-19_64.pickle
# 本旅次有幾筆:  1826
# 旅次名稱:  2020-09-11_89.pickle
# 本旅次有幾筆:  394
# 旅次名稱:  2020-09-09_89.pickle
# 本旅次有幾筆:  422
# 旅次名稱:  2020-09-17_74.pickle
# 本旅次有幾筆:  278
# 旅次名稱:  2020-09-03_83.pickle
# 本旅次有幾筆:  681
# 旅次名稱:  2020-10-04_67.pickle
# 本旅次有幾筆:  207
# 旅次名稱:  2020-10-12_91.pickle
# 本旅次有幾筆:  484
# 旅次名稱:  2020-09-03_87.pickle
# 本旅次有幾筆:  494
# 旅次名稱:  2020-09-11_92.pickle
# 本旅次有幾筆:  623
# 旅次名稱:  2020-10-13_79.pickle
# 本旅次有幾筆:  201
# 旅次名稱:  2020-09-21_64.pickle
# 本旅次有幾筆:  293
# 旅次名稱:  2020-09-07_89.pickle
# 本旅次有幾筆:  626
# 旅次名稱:  2020-09-10_81.pickle
# 本旅次有幾筆:  385
# 旅次名稱:  2020-10-25_53.pickle
# 本旅次有幾筆:  47
# 旅次名稱:  2020-10-18_85.pickle
# 本旅次有幾筆:  1393
# 旅次名稱:  2020-10-20_78.pickle
# 本旅次有幾筆:  461
# 旅次名稱:  2020-09-15_97.pickle
# 本旅次有幾筆:  228
# 旅次名稱:  2020-09-16_82.pickle
# 本旅次有幾筆:  504
# 旅次名稱:  2020-09-14_86.pickle
# 本旅次有幾筆:  436
# 旅次名稱:  2020-10-06_85.pickle
# 本旅次有幾筆:  639
# 旅次名稱:  2020-09-01_94.pickle
# 本旅次有幾筆:  442
# 旅次名稱:  2020-09-06_76.pickle
# 本旅次有幾筆:  231
# 旅次名稱:  2020-09-24_89.pickle
# 本旅次有幾筆:  357
# 旅次名稱:  2020-10-15_112.pickle
# 本旅次有幾筆:  625
# 旅次名稱:  2020-09-22_91.pickle
# 本旅次有幾筆:  623
# 旅次名稱:  2020-10-23_74.pickle
# 本旅次有幾筆:  544
# 旅次名稱:  2020-10-15_115.pickle
# 旅次名稱:  2020-09-20_260.pickle
# 本旅次有幾筆:  151
# 旅次名稱:  2020-10-01_126.pickle
# 本旅次有幾筆:  221
# 旅次名稱:  2020-09-16_373.pickle
# 本旅次有幾筆:  516
# 旅次名稱:  2020-10-28_325.pickle
# 本旅次有幾筆:  265
# 旅次名稱:  2020-09-30_304.pickle
# 本旅次有幾筆:  113
# 旅次名稱:  2020-10-17_280.pickle
# 本旅次有幾筆:  547
# 旅次名稱:  2020-10-23_324.pickle
# 本旅次有幾筆:  114
# 旅次名稱:  2020-09-10_378.pickle
# 本旅次有幾筆:  92
# 旅次名稱:  2020-09-09_370.pickle
# 本旅次有幾筆:  311
# 旅次名稱:  2020-09-25_296.pickle
# 本旅次有幾筆:  1398
# 旅次名稱:  2020-09-24_348.pickle
# 本旅次有幾筆:  49
# 旅次名稱:  2020-10-10_217.pickle
# 本旅次有幾筆:  655
# 旅次名稱:  2020-10-16_324.pickle
# 本旅次有幾筆:  498
# 旅次名稱:  2020-10-03_108.pickle
# 本旅次有幾筆:  1968
# 旅次名稱:  2020-10-05_344.pickle
# 本旅次有幾筆:  448
# 旅次名稱:  2020-10-13_309.pickle
# 本旅次有幾筆:  9
# 旅次名稱:  2020-10-24_305.pickle
# 本旅次有幾筆:  1538
# 旅次名稱:  2020-10-23_323.pickle
# 本旅次有幾筆:  295
# 旅次名稱:  2020-09-28_274.pickle
# 本旅次有幾筆:  375
# 本駕駛有290筆的資料 .
#
#
# ---------------------------------------
# 總共有2644筆超過600的資料.
# 總共有1602252筆資料x
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8d96cacb0cf4> in <module>
#      37
#      38 end = time.time()
# ---> 39 print(start, end)
#      40 print("執行時間：%f 秒" % (end - start))
#      41
#
# NameError: name 'start' is not defined

# %%
import pandas as pd
import numpy as np

# %%
# 取得各col的mean std
def get_meanstd(col):
    # load 全部原始資料
    X = pd.read_csv(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/DATA_All/X_all.csv")
    #分別取得個軸的mean std
    if col == 'x':
        mean = np.nanmean(X.x)
        std = np.nanstd(X.x)
        return mean, std
    if col == 'y':
        mean = np.nanmean(X.y)
        std = np.nanstd(X.y)
        return mean, std        
    if col == 'z':    
        mean = np.nanmean(X.z)
        std = np.nanstd(X.z)
        return mean, std
    if col == 'yaw':
        mean = np.nanmean(X.yaw)
        std = np.nanstd(X.yaw)
        return mean, std
    if col == 'roll':
        mean = np.nanmean(X.roll)
        std = np.nanstd(X.roll)
        return mean, std
    if col == 'pitch':
        mean = np.nanmean(X.pitch)
        std = np.nanstd(X.pitch)
        return mean, std
# 正規
def normalize(col, ts):
    mean, std = get_meanstd(col)
    return (ts - mean) / std

from sklearn.preprocessing import MinMaxScaler, StandardScaler                               

# 正規+切window
def Normalized_window_sliding(data, window_size, scaler_type ,scale=True):
    #先對X做正規化+平移窗格
    _l = len(data) 
    data = scaler_type().fit_transform(data)
    Xs = []
    for i in range(0, (_l - window_size+1)):
    # because this is an autoencoder - our Ys are the same as our Xs. No need to pull the next sequence of values
        Xs.append(data[i:i+window_size])
    print(f'資料形狀: {len(Xs)}')
    return (Xs)
# 切window
def window_sliding(data, window_size):
    #先對X做正規化+平移窗格
    _l = len(data) 
    Xs = []
    for i in range(0, (_l - window_size+1)):
    # because this is an autoencoder - our Ys are the same as our Xs. No need to pull the next sequence of values
        Xs.append(data[i:i+window_size])
    print(f'資料形狀: {len(Xs)}')
    return (Xs)

#按照不同閾值切label
def label_level_3_05(value):
    if value < (mean - 0.5* std):
        return str(1)
    elif value > (mean - 0.5* std) and  value < (mean + 0.5* std):
        return str(2)
    else:
        return str(3)
    
def label_level_3_1(value):
    if value < (mean - 1* std):
        return str(1)
    elif value > (mean - 1* std) and  value < (mean + 1* std):
        return str(2)
    else:
        return str(3) 
    
def label_level_3_15(value):
    if value < (mean - 1.5* std):
        return str(1)
    elif value > (mean - 1.5* std) and  value < (mean + 1.5* std):
        return str(2)
    else:
        return str(3)

# %% [markdown]
# # main
# # 對每趟旅次資料夾的資料作處理、LABEL

# %%
# --------------main--------------
# -------------做score------------

import pandas as pd
import time
import os
import pickle
import SCORE
from shutil import copyfile

start = time.time()
################
Bdriverid=[31932651,31931745,31929871,31932404,31902662,
           31932370,31928725,31932602,31931992,31902118]            

X_count=0
X_w_count=0
# Y_count=0
Y_w_count=0
df_count=0
# X_N_W=np.empty(shape=(0,3,6))  #用來放以切之X

for driver in Bdriverid:
    print('正在執行駕駛: ', driver ,'...')
#     pickle_list = glob.glob(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/{driver}/*.pickle')#回傳檔案的路近
    pickle_list = os.listdir(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/') #回傳檔案名+副檔名
    print('本駕駛有幾趟旅次: ', len(pickle_list))
    
    _count=0 
    for p in pickle_list:
        print('旅次名稱: ', p)
        file_name = p.split(".")[0] #分開檔名與副檔名
        with open (f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{p}/{p}.pickle', 'rb') as f:
            d=pickle.load(f)
        print('本旅次有幾筆: ', len(d['time_data']))
        # 每旅次抓出time_data
        if len(d['time_data'])>600 :
            
#             df_x = pd.DataFrame(columns=['_time', 'x', 'y','z','yaw','roll','pitch','car_id','journey_id'] )
            df_y = pd.DataFrame(columns=['score_3s_x','score_3s_y','score_3s_z','score_3s_yaw','score_3s_roll',
                             'score_3s_pitch','score_3s_all'])

            df_XN =  pd.DataFrame(columns=['x', 'y','z','yaw','roll','pitch','car_id','journey_id'] )

            X_N_W=np.empty(shape=(0,3,6))  #用來放以切之X

            print('--main----go------')
            df_t = pd.DataFrame(d['time_data'])

            df_xn = pd.DataFrame() #紀載個軸的x
            df_s = pd.DataFrame() #放切割後 每軸的分數                  
            x_n = []  # 存放每一軸
            column = ['x','y','z','yaw','roll','pitch']
            for col in column:
                ts = normalize(col , df_t[col])
                
                df_xn[col] = ts  #紀載個軸的x
                
                ##### 計算scoring
                x1 = SCORE.SAX_trans(ts=ts,w=len(df_t[col]),alpha=7)  #讀進物件
                x2 = x1.to_sax2()
                #SAX是一整串字串 ex:'123456789',進行分割
                x2_splited = []
                for s in range(len(x2)-2):
                    x2_splited.append(x2[s:s+3])
#                 print('score_3s'+col+'未來的個數: ', len(x2_splited)) #應該要跟len(data_3s)一樣
                #做分數
                score = SCORE.sax2_to_score.score_3s(x2_splited)
        
                # 存在dataframe
                df_s['score_3s_'+ col ] = score
            #計算 score_3s_all
            df_s['score_3s_all'] = df_s['score_3s_x']+df_s['score_3s_y']+df_s['score_3s_z']+df_s['score_3s_yaw']+df_s['score_3s_roll']+df_s['score_3s_pitch']                
            #放入Y
            df_y = df_y.append(df_s)    #儲存儲存score            
            df_y.to_csv(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/score.csv", index=False)
            
            #3class切分
            #get 母體Y的平均標準差>>給labeling使用
            Y = pd.read_csv("/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/DATA_All/score.csv")
            score_3s_all = Y["score_3s_all"]
            mean = np.mean(score_3s_all.values)
            std = np.std(score_3s_all.values)
            print('母體Y的平均、標準差: ', mean, std)
            
            #取旅次的六軸分數  做labeling
            df_y['level_3_05s'] = df_y.score_3s_all.apply(label_level_3_05)
            df_y['level_3_1s'] = df_y.score_3s_all.apply(label_level_3_1)
            df_y['level_3_15s'] = df_y.score_3s_all.apply(label_level_3_15)
            print("本旅次Y值分類(df_y['level_3_05s'])的shape: ", df_y['level_3_05s'].shape)
            print("本旅次Y值分類(df_y['score_3s_all'])的shape: ", df_y['score_3s_all'].shape)
            #先儲存
            df_y["level_3_05s"].to_csv(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/Y_level3_05s.csv", index=False)
            df_y["level_3_1s"].to_csv(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/Y_level3_1s.csv", index=False)
            df_y["level_3_15s"].to_csv(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/Y_level3_15s.csv", index=False)


            #做y軸的分數
            score_3s_y = Y["score_3s_y"]
            mean = np.mean(score_3s_y.values)
            std = np.std(score_3s_y.values)
            print('母體Y的y軸平均、標準差: ', mean, std)
            
            #取旅次的Y值 做labeling
            df_y['level_3_05s_y'] = df_y.score_3s_y.apply(label_level_3_05)
            df_y['level_3_1s_y'] = df_y.score_3s_y.apply(label_level_3_1)
            df_y['level_3_15s_y'] = df_y.score_3s_y.apply(label_level_3_15)
            print("本旅次Y值分類(df_y['level_3_05s_y'])的shape: ", df_y['level_3_05s_y'].shape)
            print("本旅次Y值分類(df_y['score_3s_all'])的shape: ", df_y['score_3s_all'].shape)
            #先儲存
            df_y["level_3_05s_y"].to_csv(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/Y_level3_05s_y.csv", index=False)
            df_y["level_3_1s_y"].to_csv(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/Y_level3_1s_y.csv", index=False)
            df_y["level_3_15s_y"].to_csv(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/Y_level3_15s_y.csv", index=False)
            
            
            
            # 處理X，進行視窗切割
            x_nw = window_sliding(df_xn, 3)
            x_nw = np.array(x_nw)
            X_N_W = np.concatenate([X_N_W,x_nw])
            print(f'切割後的X形狀: {X_N_W.shape}')

            
            df_xn['journey_id']=file_name  #加入journey
            df_xn['car_id'] = df_t['car_id']
            df_XN = df_XN.append(df_xn)  #儲存timedata正規化後加上屢次
            


            _count+=1 #算本駕駛超過600旅次數
            df_count+=1 #算總共超過600旅次數
            
            
            print('----------本旅次分數、分類 計算完畢----------------') 

            
            df_y.to_csv(f"/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/score.csv", index=False)
            df_XN.to_csv(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/X_n.csv', index=False)
            pd.DataFrame(X_N_W.reshape(-1,18)).to_csv(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/X.csv', index=False)
            print('----------本旅次儲存完畢----------------')   
            print(f'總共有{len(df_XN)}筆資料x')
            print(f'總共有{len(X_N_W)}筆切割過的資料X, 總共有{len(df_y)}筆資料y ........')
            print(f'切割後的X形狀: {X_N_W.shape}, 切割後的Y形狀: {df_y.shape} ......') 
            # 只取X_y
            XR = X_N_W.reshape(-1,6)
            XRR = pd.DataFrame(XR[:,1])
            XRR.to_csv(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/X_y.csv', index=False)           
            print(f'總共有{len(XRR)}筆切割過的資料X_y, 總共有{len(df_y)}筆資料y ........')
            #統計
            sta={}
            sta['旅次筆數'] = len(d['time_data'])
            sta['X_N_W筆數'] = len(X_N_W)       
                                 
            unique, counts = np.unique(df_y["level_3_05s"], return_counts=True)
            sta['05s類別筆數'] = counts
            unique, counts = np.unique(df_y["level_3_1s"], return_counts=True)
            sta['1s類別筆數'] = counts
            unique, counts = np.unique(df_y["level_3_15s"], return_counts=True)
            sta['15s類別筆數'] = counts
            np.save(f'/3T_HD/Neng/智慧機車_data/data_中山_bydriver/Best_10_drivers/DATA_10_AllNormal_大於600_by_journey/{driver}/{file_name}/stastistic.npy', sta)              
                        
            
            X_count += len(d['time_data'])
            X_w_count += len(X_N_W)
            Y_w_count += len(df_y)
            print('下一個旅程 ...')
    
    print(f'本駕駛有{_count}筆>600的資料 .')
    print("下一個駕駛 ...")
    print('\n')
print('---------------------------------------')
print(f'總共有{df_count}筆>600的資料.')
print(f'總共有{X_count}筆x的資料.')
print(f'總共有{X_w_count}筆切割窗格過的x資料.')


end = time.time()
print(start, end)
print("執行時間：%f 秒" % (end - start))

#X_N_W  做X
#df_XN 儲存 X正規化後的資料
# df_y儲存各columns 的分數、加上分級
# Y 做Y
# Out:
# 正在執行駕駛:  31932651 ...
# 本駕駛有幾趟旅次:  69
# 旅次名稱:  2020-10-29_81
# 本旅次有幾筆:  670
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (668,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (668,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (668,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (668,)
# 資料形狀: 668
# 切割後的X形狀: (668, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有670筆資料x
# 總共有668筆切割過的資料X, 總共有668筆資料y ........
# 切割後的X形狀: (668, 3, 6), 切割後的Y形狀: (668, 13) ......
# 總共有2004筆切割過的資料X_y, 總共有668筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-15_94
# 本旅次有幾筆:  699
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (697,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (697,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (697,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (697,)
# 資料形狀: 697
# 切割後的X形狀: (697, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有699筆資料x
# 總共有697筆切割過的資料X, 總共有697筆資料y ........
# 切割後的X形狀: (697, 3, 6), 切割後的Y形狀: (697, 13) ......
# 總共有2091筆切割過的資料X_y, 總共有697筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-11_92
# 本旅次有幾筆:  623
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (621,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (621,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (621,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (621,)
# 資料形狀: 621
# 切割後的X形狀: (621, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有623筆資料x
# 總共有621筆切割過的資料X, 總共有621筆資料y ........
# 切割後的X形狀: (621, 3, 6), 切割後的Y形狀: (621, 13) ......
# 總共有1863筆切割過的資料X_y, 總共有621筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-24_67
# 本旅次有幾筆:  649
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (647,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (647,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (647,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (647,)
# 資料形狀: 647
# 切割後的X形狀: (647, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有649筆資料x
# 總共有647筆切割過的資料X, 總共有647筆資料y ........
# 切割後的X形狀: (647, 3, 6), 切割後的Y形狀: (647, 13) ......
# 總共有1941筆切割過的資料X_y, 總共有647筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-16_84
# 本旅次有幾筆:  648
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (646,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (646,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (646,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (646,)
# 資料形狀: 646
# 切割後的X形狀: (646, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有648筆資料x
# 總共有646筆切割過的資料X, 總共有646筆資料y ........
# 切割後的X形狀: (646, 3, 6), 切割後的Y形狀: (646, 13) ......
# 總共有1938筆切割過的資料X_y, 總共有646筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-12_94
# 本旅次有幾筆:  750
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (748,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (748,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (748,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (748,)
# 資料形狀: 748
# 切割後的X形狀: (748, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有750筆資料x
# 總共有748筆切割過的資料X, 總共有748筆資料y ........
# 切割後的X形狀: (748, 3, 6), 切割後的Y形狀: (748, 13) ......
# 總共有2244筆切割過的資料X_y, 總共有748筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-23_77
# 本旅次有幾筆:  1163
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1161,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1161,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1161,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1161,)
# 資料形狀: 1161
# 切割後的X形狀: (1161, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1163筆資料x
# 總共有1161筆切割過的資料X, 總共有1161筆資料y ........
# 切割後的X形狀: (1161, 3, 6), 切割後的Y形狀: (1161, 13) ......
# 總共有3483筆切割過的資料X_y, 總共有1161筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-25_65
# 本旅次有幾筆:  1140
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1138,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1138,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1138,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1138,)
# 資料形狀: 1138
# 切割後的X形狀: (1138, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1140筆資料x
# 總共有1138筆切割過的資料X, 總共有1138筆資料y ........
# 切割後的X形狀: (1138, 3, 6), 切割後的Y形狀: (1138, 13) ......
# 總共有3414筆切割過的資料X_y, 總共有1138筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-07_89
# 本旅次有幾筆:  626
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (624,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (624,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (624,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (624,)
# 資料形狀: 624
# 切割後的X形狀: (624, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有626筆資料x
# 總共有624筆切割過的資料X, 總共有624筆資料y ........
# 切割後的X形狀: (624, 3, 6), 切割後的Y形狀: (624, 13) ......
# 總共有1872筆切割過的資料X_y, 總共有624筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-06_83
# 本旅次有幾筆:  785
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (783,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (783,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (783,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (783,)
# 資料形狀: 783
# 切割後的X形狀: (783, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有785筆資料x
# 總共有783筆切割過的資料X, 總共有783筆資料y ........
# 切割後的X形狀: (783, 3, 6), 切割後的Y形狀: (783, 13) ......
# 總共有2349筆切割過的資料X_y, 總共有783筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-20_76
# 本旅次有幾筆:  715
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (713,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (713,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (713,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (713,)
# 資料形狀: 713
# 切割後的X形狀: (713, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有715筆資料x
# 總共有713筆切割過的資料X, 總共有713筆資料y ........
# 切割後的X形狀: (713, 3, 6), 切割後的Y形狀: (713, 13) ......
# 總共有2139筆切割過的資料X_y, 總共有713筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-18_85
# 本旅次有幾筆:  1393
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1391,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1391,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1391,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1391,)
# 資料形狀: 1391
# 切割後的X形狀: (1391, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1393筆資料x
# 總共有1391筆切割過的資料X, 總共有1391筆資料y ........
# 切割後的X形狀: (1391, 3, 6), 切割後的Y形狀: (1391, 13) ......
# 總共有4173筆切割過的資料X_y, 總共有1391筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-13_66
# 本旅次有幾筆:  1089
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1087,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1087,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1087,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1087,)
# 資料形狀: 1087
# 切割後的X形狀: (1087, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1089筆資料x
# 總共有1087筆切割過的資料X, 總共有1087筆資料y ........
# 切割後的X形狀: (1087, 3, 6), 切割後的Y形狀: (1087, 13) ......
# 總共有3261筆切割過的資料X_y, 總共有1087筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-22_91
# 本旅次有幾筆:  623
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (621,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (621,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (621,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (621,)
# 資料形狀: 621
# 切割後的X形狀: (621, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有623筆資料x
# 總共有621筆切割過的資料X, 總共有621筆資料y ........
# 切割後的X形狀: (621, 3, 6), 切割後的Y形狀: (621, 13) ......
# 總共有1863筆切割過的資料X_y, 總共有621筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-20_61
# 本旅次有幾筆:  631
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (629,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (629,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (629,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (629,)
# 資料形狀: 629
# 切割後的X形狀: (629, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有631筆資料x
# 總共有629筆切割過的資料X, 總共有629筆資料y ........
# 切割後的X形狀: (629, 3, 6), 切割後的Y形狀: (629, 13) ......
# 總共有1887筆切割過的資料X_y, 總共有629筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-08_92
# 本旅次有幾筆:  1743
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1741,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1741,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1741,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1741,)
# 資料形狀: 1741
# 切割後的X形狀: (1741, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1743筆資料x
# 總共有1741筆切割過的資料X, 總共有1741筆資料y ........
# 切割後的X形狀: (1741, 3, 6), 切割後的Y形狀: (1741, 13) ......
# 總共有5223筆切割過的資料X_y, 總共有1741筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-06_75
# 本旅次有幾筆:  844
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (842,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (842,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (842,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (842,)
# 資料形狀: 842
# 切割後的X形狀: (842, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有844筆資料x
# 總共有842筆切割過的資料X, 總共有842筆資料y ........
# 切割後的X形狀: (842, 3, 6), 切割後的Y形狀: (842, 13) ......
# 總共有2526筆切割過的資料X_y, 總共有842筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-08_89
# 本旅次有幾筆:  618
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (616,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (616,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (616,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (616,)
# 資料形狀: 616
# 切割後的X形狀: (616, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有618筆資料x
# 總共有616筆切割過的資料X, 總共有616筆資料y ........
# 切割後的X形狀: (616, 3, 6), 切割後的Y形狀: (616, 13) ......
# 總共有1848筆切割過的資料X_y, 總共有616筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-17_77
# 本旅次有幾筆:  1224
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1222,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1222,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1222,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1222,)
# 資料形狀: 1222
# 切割後的X形狀: (1222, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1224筆資料x
# 總共有1222筆切割過的資料X, 總共有1222筆資料y ........
# 切割後的X形狀: (1222, 3, 6), 切割後的Y形狀: (1222, 13) ......
# 總共有3666筆切割過的資料X_y, 總共有1222筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-23_78
# 本旅次有幾筆:  986
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (984,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (984,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (984,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (984,)
# 資料形狀: 984
# 切割後的X形狀: (984, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有986筆資料x
# 總共有984筆切割過的資料X, 總共有984筆資料y ........
# 切割後的X形狀: (984, 3, 6), 切割後的Y形狀: (984, 13) ......
# 總共有2952筆切割過的資料X_y, 總共有984筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-03_83
# 本旅次有幾筆:  681
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (679,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (679,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (679,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (679,)
# 資料形狀: 679
# 切割後的X形狀: (679, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有681筆資料x
# 總共有679筆切割過的資料X, 總共有679筆資料y ........
# 切割後的X形狀: (679, 3, 6), 切割後的Y形狀: (679, 13) ......
# 總共有2037筆切割過的資料X_y, 總共有679筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-22_89
# 本旅次有幾筆:  669
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (667,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (667,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (667,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (667,)
# 資料形狀: 667
# 切割後的X形狀: (667, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有669筆資料x
# 總共有667筆切割過的資料X, 總共有667筆資料y ........
# 切割後的X形狀: (667, 3, 6), 切割後的Y形狀: (667, 13) ......
# 總共有2001筆切割過的資料X_y, 總共有667筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-13_62
# 本旅次有幾筆:  621
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (619,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (619,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (619,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (619,)
# 資料形狀: 619
# 切割後的X形狀: (619, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有621筆資料x
# 總共有619筆切割過的資料X, 總共有619筆資料y ........
# 切割後的X形狀: (619, 3, 6), 切割後的Y形狀: (619, 13) ......
# 總共有1857筆切割過的資料X_y, 總共有619筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-04_66
# 本旅次有幾筆:  1496
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1494,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1494,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1494,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1494,)
# 資料形狀: 1494
# 切割後的X形狀: (1494, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1496筆資料x
# 總共有1494筆切割過的資料X, 總共有1494筆資料y ........
# 切割後的X形狀: (1494, 3, 6), 切割後的Y形狀: (1494, 13) ......
# 總共有4482筆切割過的資料X_y, 總共有1494筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-28_72
# 本旅次有幾筆:  1158
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1156,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1156,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1156,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1156,)
# 資料形狀: 1156
# 切割後的X形狀: (1156, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1158筆資料x
# 總共有1156筆切割過的資料X, 總共有1156筆資料y ........
# 切割後的X形狀: (1156, 3, 6), 切割後的Y形狀: (1156, 13) ......
# 總共有3468筆切割過的資料X_y, 總共有1156筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-23_79
# 本旅次有幾筆:  740
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (738,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (738,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (738,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (738,)
# 資料形狀: 738
# 切割後的X形狀: (738, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有740筆資料x
# 總共有738筆切割過的資料X, 總共有738筆資料y ........
# 切割後的X形狀: (738, 3, 6), 切割後的Y形狀: (738, 13) ......
# 總共有2214筆切割過的資料X_y, 總共有738筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-28_73
# 本旅次有幾筆:  1896
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1894,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1894,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1894,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1894,)
# 資料形狀: 1894
# 切割後的X形狀: (1894, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1896筆資料x
# 總共有1894筆切割過的資料X, 總共有1894筆資料y ........
# 切割後的X形狀: (1894, 3, 6), 切割後的Y形狀: (1894, 13) ......
# 總共有5682筆切割過的資料X_y, 總共有1894筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-18_76
# 本旅次有幾筆:  692
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (690,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (690,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (690,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (690,)
# 資料形狀: 690
# 切割後的X形狀: (690, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有692筆資料x
# 總共有690筆切割過的資料X, 總共有690筆資料y ........
# 切割後的X形狀: (690, 3, 6), 切割後的Y形狀: (690, 13) ......
# 總共有2070筆切割過的資料X_y, 總共有690筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-23_76
# 本旅次有幾筆:  679
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (677,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (677,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (677,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (677,)
# 資料形狀: 677
# 切割後的X形狀: (677, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有679筆資料x
# 總共有677筆切割過的資料X, 總共有677筆資料y ........
# 切割後的X形狀: (677, 3, 6), 切割後的Y形狀: (677, 13) ......
# 總共有2031筆切割過的資料X_y, 總共有677筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-23_84
# 本旅次有幾筆:  631
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (629,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (629,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (629,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (629,)
# 資料形狀: 629
# 切割後的X形狀: (629, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有631筆資料x
# 總共有629筆切割過的資料X, 總共有629筆資料y ........
# 切割後的X形狀: (629, 3, 6), 切割後的Y形狀: (629, 13) ......
# 總共有1887筆切割過的資料X_y, 總共有629筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-30_90
# 本旅次有幾筆:  937
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (935,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (935,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (935,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (935,)
# 資料形狀: 935
# 切割後的X形狀: (935, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有937筆資料x
# 總共有935筆切割過的資料X, 總共有935筆資料y ........
# 切割後的X形狀: (935, 3, 6), 切割後的Y形狀: (935, 13) ......
# 總共有2805筆切割過的資料X_y, 總共有935筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-25_66
# 本旅次有幾筆:  1293
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1291,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1291,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1291,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1291,)
# 資料形狀: 1291
# 切割後的X形狀: (1291, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1293筆資料x
# 總共有1291筆切割過的資料X, 總共有1291筆資料y ........
# 切割後的X形狀: (1291, 3, 6), 切割後的Y形狀: (1291, 13) ......
# 總共有3873筆切割過的資料X_y, 總共有1291筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-13_60
# 本旅次有幾筆:  1839
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1837,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1837,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1837,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1837,)
# 資料形狀: 1837
# 切割後的X形狀: (1837, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1839筆資料x
# 總共有1837筆切割過的資料X, 總共有1837筆資料y ........
# 切割後的X形狀: (1837, 3, 6), 切割後的Y形狀: (1837, 13) ......
# 總共有5511筆切割過的資料X_y, 總共有1837筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-29_77
# 本旅次有幾筆:  624
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (622,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (622,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (622,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (622,)
# 資料形狀: 622
# 切割後的X形狀: (622, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有624筆資料x
# 總共有622筆切割過的資料X, 總共有622筆資料y ........
# 切割後的X形狀: (622, 3, 6), 切割後的Y形狀: (622, 13) ......
# 總共有1866筆切割過的資料X_y, 總共有622筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-25_69
# 本旅次有幾筆:  1610
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1608,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1608,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1608,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1608,)
# 資料形狀: 1608
# 切割後的X形狀: (1608, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1610筆資料x
# 總共有1608筆切割過的資料X, 總共有1608筆資料y ........
# 切割後的X形狀: (1608, 3, 6), 切割後的Y形狀: (1608, 13) ......
# 總共有4824筆切割過的資料X_y, 總共有1608筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-08_90
# 本旅次有幾筆:  618
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (616,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (616,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (616,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (616,)
# 資料形狀: 616
# 切割後的X形狀: (616, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有618筆資料x
# 總共有616筆切割過的資料X, 總共有616筆資料y ........
# 切割後的X形狀: (616, 3, 6), 切割後的Y形狀: (616, 13) ......
# 總共有1848筆切割過的資料X_y, 總共有616筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-15_93
# 本旅次有幾筆:  605
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (603,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (603,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (603,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (603,)
# 資料形狀: 603
# 切割後的X形狀: (603, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有605筆資料x
# 總共有603筆切割過的資料X, 總共有603筆資料y ........
# 切割後的X形狀: (603, 3, 6), 切割後的Y形狀: (603, 13) ......
# 總共有1809筆切割過的資料X_y, 總共有603筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-29_76
# 本旅次有幾筆:  605
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (603,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (603,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (603,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (603,)
# 資料形狀: 603
# 切割後的X形狀: (603, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有605筆資料x
# 總共有603筆切割過的資料X, 總共有603筆資料y ........
# 切割後的X形狀: (603, 3, 6), 切割後的Y形狀: (603, 13) ......
# 總共有1809筆切割過的資料X_y, 總共有603筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-04_88
# 本旅次有幾筆:  1114
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1112,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1112,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1112,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1112,)
# 資料形狀: 1112
# 切割後的X形狀: (1112, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1114筆資料x
# 總共有1112筆切割過的資料X, 總共有1112筆資料y ........
# 切割後的X形狀: (1112, 3, 6), 切割後的Y形狀: (1112, 13) ......
# 總共有3336筆切割過的資料X_y, 總共有1112筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-17_72
# 本旅次有幾筆:  732
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (730,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (730,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (730,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (730,)
# 資料形狀: 730
# 切割後的X形狀: (730, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有732筆資料x
# 總共有730筆切割過的資料X, 總共有730筆資料y ........
# 切割後的X形狀: (730, 3, 6), 切割後的Y形狀: (730, 13) ......
# 總共有2190筆切割過的資料X_y, 總共有730筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-17_78
# 本旅次有幾筆:  877
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (875,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (875,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (875,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (875,)
# 資料形狀: 875
# 切割後的X形狀: (875, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有877筆資料x
# 總共有875筆切割過的資料X, 總共有875筆資料y ........
# 切割後的X形狀: (875, 3, 6), 切割後的Y形狀: (875, 13) ......
# 總共有2625筆切割過的資料X_y, 總共有875筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-19_65
# 本旅次有幾筆:  1224
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1222,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1222,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1222,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1222,)
# 資料形狀: 1222
# 切割後的X形狀: (1222, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1224筆資料x
# 總共有1222筆切割過的資料X, 總共有1222筆資料y ........
# 切割後的X形狀: (1222, 3, 6), 切割後的Y形狀: (1222, 13) ......
# 總共有3666筆切割過的資料X_y, 總共有1222筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-15_95
# 本旅次有幾筆:  855
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (853,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (853,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (853,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (853,)
# 資料形狀: 853
# 切割後的X形狀: (853, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有855筆資料x
# 總共有853筆切割過的資料X, 總共有853筆資料y ........
# 切割後的X形狀: (853, 3, 6), 切割後的Y形狀: (853, 13) ......
# 總共有2559筆切割過的資料X_y, 總共有853筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-06_84
# 本旅次有幾筆:  703
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (701,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (701,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (701,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (701,)
# 資料形狀: 701
# 切割後的X形狀: (701, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有703筆資料x
# 總共有701筆切割過的資料X, 總共有701筆資料y ........
# 切割後的X形狀: (701, 3, 6), 切割後的Y形狀: (701, 13) ......
# 總共有2103筆切割過的資料X_y, 總共有701筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-04_86
# 本旅次有幾筆:  686
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (684,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (684,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (684,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (684,)
# 資料形狀: 684
# 切割後的X形狀: (684, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有686筆資料x
# 總共有684筆切割過的資料X, 總共有684筆資料y ........
# 切割後的X形狀: (684, 3, 6), 切割後的Y形狀: (684, 13) ......
# 總共有2052筆切割過的資料X_y, 總共有684筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-04_87
# 本旅次有幾筆:  670
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (668,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (668,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (668,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (668,)
# 資料形狀: 668
# 切割後的X形狀: (668, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有670筆資料x
# 總共有668筆切割過的資料X, 總共有668筆資料y ........
# 切割後的X形狀: (668, 3, 6), 切割後的Y形狀: (668, 13) ......
# 總共有2004筆切割過的資料X_y, 總共有668筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-15_112
# 本旅次有幾筆:  625
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (623,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (623,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (623,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (623,)
# 資料形狀: 623
# 切割後的X形狀: (623, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有625筆資料x
# 總共有623筆切割過的資料X, 總共有623筆資料y ........
# 切割後的X形狀: (623, 3, 6), 切割後的Y形狀: (623, 13) ......
# 總共有1869筆切割過的資料X_y, 總共有623筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-19_64
# 本旅次有幾筆:  1826
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1824,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1824,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1824,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1824,)
# 資料形狀: 1824
# 切割後的X形狀: (1824, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1826筆資料x
# 總共有1824筆切割過的資料X, 總共有1824筆資料y ........
# 切割後的X形狀: (1824, 3, 6), 切割後的Y形狀: (1824, 13) ......
# 總共有5472筆切割過的資料X_y, 總共有1824筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-01_43
# 本旅次有幾筆:  724
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (722,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (722,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (722,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (722,)
# 資料形狀: 722
# 切割後的X形狀: (722, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有724筆資料x
# 總共有722筆切割過的資料X, 總共有722筆資料y ........
# 切割後的X形狀: (722, 3, 6), 切割後的Y形狀: (722, 13) ......
# 總共有2166筆切割過的資料X_y, 總共有722筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-10_82
# 本旅次有幾筆:  864
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (862,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (862,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (862,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (862,)
# 資料形狀: 862
# 切割後的X形狀: (862, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有864筆資料x
# 總共有862筆切割過的資料X, 總共有862筆資料y ........
# 切割後的X形狀: (862, 3, 6), 切割後的Y形狀: (862, 13) ......
# 總共有2586筆切割過的資料X_y, 總共有862筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-13_67
# 本旅次有幾筆:  1285
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1283,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1283,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1283,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1283,)
# 資料形狀: 1283
# 切割後的X形狀: (1283, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1285筆資料x
# 總共有1283筆切割過的資料X, 總共有1283筆資料y ........
# 切割後的X形狀: (1283, 3, 6), 切割後的Y形狀: (1283, 13) ......
# 總共有3849筆切割過的資料X_y, 總共有1283筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-12_92
# 本旅次有幾筆:  610
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (608,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (608,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (608,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (608,)
# 資料形狀: 608
# 切割後的X形狀: (608, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有610筆資料x
# 總共有608筆切割過的資料X, 總共有608筆資料y ........
# 切割後的X形狀: (608, 3, 6), 切割後的Y形狀: (608, 13) ......
# 總共有1824筆切割過的資料X_y, 總共有608筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-01_41
# 本旅次有幾筆:  1171
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1169,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1169,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1169,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1169,)
# 資料形狀: 1169
# 切割後的X形狀: (1169, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1171筆資料x
# 總共有1169筆切割過的資料X, 總共有1169筆資料y ........
# 切割後的X形狀: (1169, 3, 6), 切割後的Y形狀: (1169, 13) ......
# 總共有3507筆切割過的資料X_y, 總共有1169筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-01_92
# 本旅次有幾筆:  708
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (706,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (706,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (706,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (706,)
# 資料形狀: 706
# 切割後的X形狀: (706, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有708筆資料x
# 總共有706筆切割過的資料X, 總共有706筆資料y ........
# 切割後的X形狀: (706, 3, 6), 切割後的Y形狀: (706, 13) ......
# 總共有2118筆切割過的資料X_y, 總共有706筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-16_85
# 本旅次有幾筆:  621
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (619,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (619,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (619,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (619,)
# 資料形狀: 619
# 切割後的X形狀: (619, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有621筆資料x
# 總共有619筆切割過的資料X, 總共有619筆資料y ........
# 切割後的X形狀: (619, 3, 6), 切割後的Y形狀: (619, 13) ......
# 總共有1857筆切割過的資料X_y, 總共有619筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-14_83
# 本旅次有幾筆:  1065
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1063,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1063,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1063,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1063,)
# 資料形狀: 1063
# 切割後的X形狀: (1063, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1065筆資料x
# 總共有1063筆切割過的資料X, 總共有1063筆資料y ........
# 切割後的X形狀: (1063, 3, 6), 切割後的Y形狀: (1063, 13) ......
# 總共有3189筆切割過的資料X_y, 總共有1063筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-30_91
# 本旅次有幾筆:  640
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (638,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (638,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (638,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (638,)
# 資料形狀: 638
# 切割後的X形狀: (638, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有640筆資料x
# 總共有638筆切割過的資料X, 總共有638筆資料y ........
# 切割後的X形狀: (638, 3, 6), 切割後的Y形狀: (638, 13) ......
# 總共有1914筆切割過的資料X_y, 總共有638筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-03_91
# 本旅次有幾筆:  753
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (751,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (751,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (751,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (751,)
# 資料形狀: 751
# 切割後的X形狀: (751, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有753筆資料x
# 總共有751筆切割過的資料X, 總共有751筆資料y ........
# 切割後的X形狀: (751, 3, 6), 切割後的Y形狀: (751, 13) ......
# 總共有2253筆切割過的資料X_y, 總共有751筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-21_95
# 本旅次有幾筆:  616
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (614,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (614,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (614,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (614,)
# 資料形狀: 614
# 切割後的X形狀: (614, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有616筆資料x
# 總共有614筆切割過的資料X, 總共有614筆資料y ........
# 切割後的X形狀: (614, 3, 6), 切割後的Y形狀: (614, 13) ......
# 總共有1842筆切割過的資料X_y, 總共有614筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-14_84
# 本旅次有幾筆:  602
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (600,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (600,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (600,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (600,)
# 資料形狀: 600
# 切割後的X形狀: (600, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有602筆資料x
# 總共有600筆切割過的資料X, 總共有600筆資料y ........
# 切割後的X形狀: (600, 3, 6), 切割後的Y形狀: (600, 13) ......
# 總共有1800筆切割過的資料X_y, 總共有600筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-25_52
# 本旅次有幾筆:  644
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (642,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (642,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (642,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (642,)
# 資料形狀: 642
# 切割後的X形狀: (642, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有644筆資料x
# 總共有642筆切割過的資料X, 總共有642筆資料y ........
# 切割後的X形狀: (642, 3, 6), 切割後的Y形狀: (642, 13) ......
# 總共有1926筆切割過的資料X_y, 總共有642筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-22_88
# 本旅次有幾筆:  613
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (611,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (611,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (611,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (611,)
# 資料形狀: 611
# 切割後的X形狀: (611, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有613筆資料x
# 總共有611筆切割過的資料X, 總共有611筆資料y ........
# 切割後的X形狀: (611, 3, 6), 切割後的Y形狀: (611, 13) ......
# 總共有1833筆切割過的資料X_y, 總共有611筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-30_91
# 本旅次有幾筆:  1076
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1074,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1074,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1074,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1074,)
# 資料形狀: 1074
# 切割後的X形狀: (1074, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1076筆資料x
# 總共有1074筆切割過的資料X, 總共有1074筆資料y ........
# 切割後的X形狀: (1074, 3, 6), 切割後的Y形狀: (1074, 13) ......
# 總共有3222筆切割過的資料X_y, 總共有1074筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-06_85
# 本旅次有幾筆:  639
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (637,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (637,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (637,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (637,)
# 資料形狀: 637
# 切割後的X形狀: (637, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有639筆資料x
# 總共有637筆切割過的資料X, 總共有637筆資料y ........
# 切割後的X形狀: (637, 3, 6), 切割後的Y形狀: (637, 13) ......
# 總共有1911筆切割過的資料X_y, 總共有637筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-11_91
# 本旅次有幾筆:  732
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (730,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (730,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (730,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (730,)
# 資料形狀: 730
# 切割後的X形狀: (730, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有732筆資料x
# 總共有730筆切割過的資料X, 總共有730筆資料y ........
# 切割後的X形狀: (730, 3, 6), 切割後的Y形狀: (730, 13) ......
# 總共有2190筆切割過的資料X_y, 總共有730筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-06_82
# 本旅次有幾筆:  770
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (768,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (768,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (768,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (768,)
# 資料形狀: 768
# 切割後的X形狀: (768, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有770筆資料x
# 總共有768筆切割過的資料X, 總共有768筆資料y ........
# 切割後的X形狀: (768, 3, 6), 切割後的Y形狀: (768, 13) ......
# 總共有2304筆切割過的資料X_y, 總共有768筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-12_93
# 本旅次有幾筆:  1132
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1130,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1130,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1130,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1130,)
# 資料形狀: 1130
# 切割後的X形狀: (1130, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1132筆資料x
# 總共有1130筆切割過的資料X, 總共有1130筆資料y ........
# 切割後的X形狀: (1130, 3, 6), 切割後的Y形狀: (1130, 13) ......
# 總共有3390筆切割過的資料X_y, 總共有1130筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-15_115
# 本旅次有幾筆:  1610
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1608,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1608,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1608,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1608,)
# 資料形狀: 1608
# 切割後的X形狀: (1608, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1610筆資料x
# 總共有1608筆切割過的資料X, 總共有1608筆資料y ........
# 切割後的X形狀: (1608, 3, 6), 切割後的Y形狀: (1608, 13) ......
# 總共有4824筆切割過的資料X_y, 總共有1608筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-13_65
# 本旅次有幾筆:  966
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (964,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (964,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (964,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (964,)
# 資料形狀: 964
# 切割後的X形狀: (964, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有966筆資料x
# 總共有964筆切割過的資料X, 總共有964筆資料y ........
# 切割後的X形狀: (964, 3, 6), 切割後的Y形狀: (964, 13) ......
# 總共有2892筆切割過的資料X_y, 總共有964筆資料y ........
# 下一個旅程 ...
# 本駕駛有69筆>600的資料 .
# 下一個駕駛 ...
#
#
# 正在執行駕駛:  31931745 ...
# 本駕駛有幾趟旅次:  128
# 旅次名稱:  2020-09-14_17
# 本旅次有幾筆:  612
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (610,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (610,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (610,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (610,)
# 資料形狀: 610
# 切割後的X形狀: (610, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有612筆資料x
# 總共有610筆切割過的資料X, 總共有610筆資料y ........
# 切割後的X形狀: (610, 3, 6), 切割後的Y形狀: (610, 13) ......
# 總共有1830筆切割過的資料X_y, 總共有610筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-03_5
# 本旅次有幾筆:  2040
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2038,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2038,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2038,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2038,)
# 資料形狀: 2038
# 切割後的X形狀: (2038, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2040筆資料x
# 總共有2038筆切割過的資料X, 總共有2038筆資料y ........
# 切割後的X形狀: (2038, 3, 6), 切割後的Y形狀: (2038, 13) ......
# 總共有6114筆切割過的資料X_y, 總共有2038筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-23_23
# 本旅次有幾筆:  1971
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1969,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1969,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1969,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1969,)
# 資料形狀: 1969
# 切割後的X形狀: (1969, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1971筆資料x
# 總共有1969筆切割過的資料X, 總共有1969筆資料y ........
# 切割後的X形狀: (1969, 3, 6), 切割後的Y形狀: (1969, 13) ......
# 總共有5907筆切割過的資料X_y, 總共有1969筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-17_14
# 本旅次有幾筆:  2221
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2219,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2219,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2219,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2219,)
# 資料形狀: 2219
# 切割後的X形狀: (2219, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2221筆資料x
# 總共有2219筆切割過的資料X, 總共有2219筆資料y ........
# 切割後的X形狀: (2219, 3, 6), 切割後的Y形狀: (2219, 13) ......
# 總共有6657筆切割過的資料X_y, 總共有2219筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-09_22
# 本旅次有幾筆:  2341
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2339,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2339,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2339,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2339,)
# 資料形狀: 2339
# 切割後的X形狀: (2339, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2341筆資料x
# 總共有2339筆切割過的資料X, 總共有2339筆資料y ........
# 切割後的X形狀: (2339, 3, 6), 切割後的Y形狀: (2339, 13) ......
# 總共有7017筆切割過的資料X_y, 總共有2339筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-20_20
# 本旅次有幾筆:  2473
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2471,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2471,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2471,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2471,)
# 資料形狀: 2471
# 切割後的X形狀: (2471, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2473筆資料x
# 總共有2471筆切割過的資料X, 總共有2471筆資料y ........
# 切割後的X形狀: (2471, 3, 6), 切割後的Y形狀: (2471, 13) ......
# 總共有7413筆切割過的資料X_y, 總共有2471筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-02_16
# 本旅次有幾筆:  2649
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2647,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2647,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2647,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2647,)
# 資料形狀: 2647
# 切割後的X形狀: (2647, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2649筆資料x
# 總共有2647筆切割過的資料X, 總共有2647筆資料y ........
# 切割後的X形狀: (2647, 3, 6), 切割後的Y形狀: (2647, 13) ......
# 總共有7941筆切割過的資料X_y, 總共有2647筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-09_19
# 本旅次有幾筆:  2151
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2149,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2149,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2149,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2149,)
# 資料形狀: 2149
# 切割後的X形狀: (2149, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2151筆資料x
# 總共有2149筆切割過的資料X, 總共有2149筆資料y ........
# 切割後的X形狀: (2149, 3, 6), 切割後的Y形狀: (2149, 13) ......
# 總共有6447筆切割過的資料X_y, 總共有2149筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-21_20
# 本旅次有幾筆:  2519
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2517,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2517,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2517,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2517,)
# 資料形狀: 2517
# 切割後的X形狀: (2517, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2519筆資料x
# 總共有2517筆切割過的資料X, 總共有2517筆資料y ........
# 切割後的X形狀: (2517, 3, 6), 切割後的Y形狀: (2517, 13) ......
# 總共有7551筆切割過的資料X_y, 總共有2517筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-11_22
# 本旅次有幾筆:  1356
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1354,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1354,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1354,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1354,)
# 資料形狀: 1354
# 切割後的X形狀: (1354, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1356筆資料x
# 總共有1354筆切割過的資料X, 總共有1354筆資料y ........
# 切割後的X形狀: (1354, 3, 6), 切割後的Y形狀: (1354, 13) ......
# 總共有4062筆切割過的資料X_y, 總共有1354筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-14_17
# 本旅次有幾筆:  850
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (848,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (848,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (848,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (848,)
# 資料形狀: 848
# 切割後的X形狀: (848, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有850筆資料x
# 總共有848筆切割過的資料X, 總共有848筆資料y ........
# 切割後的X形狀: (848, 3, 6), 切割後的Y形狀: (848, 13) ......
# 總共有2544筆切割過的資料X_y, 總共有848筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-04_26
# 本旅次有幾筆:  2462
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2460,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2460,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2460,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2460,)
# 資料形狀: 2460
# 切割後的X形狀: (2460, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2462筆資料x
# 總共有2460筆切割過的資料X, 總共有2460筆資料y ........
# 切割後的X形狀: (2460, 3, 6), 切割後的Y形狀: (2460, 13) ......
# 總共有7380筆切割過的資料X_y, 總共有2460筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-30_24
# 本旅次有幾筆:  2337
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# ...
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1026,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1026,)
# 資料形狀: 1026
# 切割後的X形狀: (1026, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1028筆資料x
# 總共有1026筆切割過的資料X, 總共有1026筆資料y ........
# 切割後的X形狀: (1026, 3, 6), 切割後的Y形狀: (1026, 13) ......
# 總共有3078筆切割過的資料X_y, 總共有1026筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-23_320
# 本旅次有幾筆:  783
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (781,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (781,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (781,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (781,)
# 資料形狀: 781
# 切割後的X形狀: (781, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有783筆資料x
# 總共有781筆切割過的資料X, 總共有781筆資料y ........
# 切割後的X形狀: (781, 3, 6), 切割後的Y形狀: (781, 13) ......
# 總共有2343筆切割過的資料X_y, 總共有781筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-23_321
# 本旅次有幾筆:  1943
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1941,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1941,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1941,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1941,)
# 資料形狀: 1941
# 切割後的X形狀: (1941, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1943筆資料x
# 總共有1941筆切割過的資料X, 總共有1941筆資料y ........
# 切割後的X形狀: (1941, 3, 6), 切割後的Y形狀: (1941, 13) ......
# 總共有5823筆切割過的資料X_y, 總共有1941筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-18_307
# 本旅次有幾筆:  1094
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1092,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1092,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1092,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1092,)
# 資料形狀: 1092
# 切割後的X形狀: (1092, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1094筆資料x
# 總共有1092筆切割過的資料X, 總共有1092筆資料y ........
# 切割後的X形狀: (1092, 3, 6), 切割後的Y形狀: (1092, 13) ......
# 總共有3276筆切割過的資料X_y, 總共有1092筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-20_258
# 本旅次有幾筆:  2146
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2144,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2144,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2144,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2144,)
# 資料形狀: 2144
# 切割後的X形狀: (2144, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2146筆資料x
# 總共有2144筆切割過的資料X, 總共有2144筆資料y ........
# 切割後的X形狀: (2144, 3, 6), 切割後的Y形狀: (2144, 13) ......
# 總共有6432筆切割過的資料X_y, 總共有2144筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-09_251
# 本旅次有幾筆:  816
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (814,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (814,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (814,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (814,)
# 資料形狀: 814
# 切割後的X形狀: (814, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有816筆資料x
# 總共有814筆切割過的資料X, 總共有814筆資料y ........
# 切割後的X形狀: (814, 3, 6), 切割後的Y形狀: (814, 13) ......
# 總共有2442筆切割過的資料X_y, 總共有814筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-26_371
# 本旅次有幾筆:  712
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (710,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (710,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (710,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (710,)
# 資料形狀: 710
# 切割後的X形狀: (710, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有712筆資料x
# 總共有710筆切割過的資料X, 總共有710筆資料y ........
# 切割後的X形狀: (710, 3, 6), 切割後的Y形狀: (710, 13) ......
# 總共有2130筆切割過的資料X_y, 總共有710筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-01_292
# 本旅次有幾筆:  767
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (765,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (765,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (765,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (765,)
# 資料形狀: 765
# 切割後的X形狀: (765, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有767筆資料x
# 總共有765筆切割過的資料X, 總共有765筆資料y ........
# 切割後的X形狀: (765, 3, 6), 切割後的Y形狀: (765, 13) ......
# 總共有2295筆切割過的資料X_y, 總共有765筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-14_327
# 本旅次有幾筆:  1252
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1250,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1250,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1250,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1250,)
# 資料形狀: 1250
# 切割後的X形狀: (1250, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1252筆資料x
# 總共有1250筆切割過的資料X, 總共有1250筆資料y ........
# 切割後的X形狀: (1250, 3, 6), 切割後的Y形狀: (1250, 13) ......
# 總共有3750筆切割過的資料X_y, 總共有1250筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-03_107
# 本旅次有幾筆:  675
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (673,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (673,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (673,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (673,)
# 資料形狀: 673
# 切割後的X形狀: (673, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有675筆資料x
# 總共有673筆切割過的資料X, 總共有673筆資料y ........
# 切割後的X形狀: (673, 3, 6), 切割後的Y形狀: (673, 13) ......
# 總共有2019筆切割過的資料X_y, 總共有673筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-03_108
# 本旅次有幾筆:  1968
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1966,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1966,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1966,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1966,)
# 資料形狀: 1966
# 切割後的X形狀: (1966, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1968筆資料x
# 總共有1966筆切割過的資料X, 總共有1966筆資料y ........
# 切割後的X形狀: (1966, 3, 6), 切割後的Y形狀: (1966, 13) ......
# 總共有5898筆切割過的資料X_y, 總共有1966筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-15_368
# 本旅次有幾筆:  1311
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1309,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1309,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1309,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1309,)
# 資料形狀: 1309
# 切割後的X形狀: (1309, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1311筆資料x
# 總共有1309筆切割過的資料X, 總共有1309筆資料y ........
# 切割後的X形狀: (1309, 3, 6), 切割後的Y形狀: (1309, 13) ......
# 總共有3927筆切割過的資料X_y, 總共有1309筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-18_308
# 本旅次有幾筆:  4302
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (4300,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (4300,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (4300,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (4300,)
# 資料形狀: 4300
# 切割後的X形狀: (4300, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有4302筆資料x
# 總共有4300筆切割過的資料X, 總共有4300筆資料y ........
# 切割後的X形狀: (4300, 3, 6), 切割後的Y形狀: (4300, 13) ......
# 總共有12900筆切割過的資料X_y, 總共有4300筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-02_260
# 本旅次有幾筆:  2348
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (2346,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2346,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (2346,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (2346,)
# 資料形狀: 2346
# 切割後的X形狀: (2346, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有2348筆資料x
# 總共有2346筆切割過的資料X, 總共有2346筆資料y ........
# 切割後的X形狀: (2346, 3, 6), 切割後的Y形狀: (2346, 13) ......
# 總共有7038筆切割過的資料X_y, 總共有2346筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-24_349
# 本旅次有幾筆:  864
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (862,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (862,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (862,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (862,)
# 資料形狀: 862
# 切割後的X形狀: (862, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有864筆資料x
# 總共有862筆切割過的資料X, 總共有862筆資料y ........
# 切割後的X形狀: (862, 3, 6), 切割後的Y形狀: (862, 13) ......
# 總共有2586筆切割過的資料X_y, 總共有862筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-31_268
# 本旅次有幾筆:  1738
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1736,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1736,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1736,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1736,)
# 資料形狀: 1736
# 切割後的X形狀: (1736, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1738筆資料x
# 總共有1736筆切割過的資料X, 總共有1736筆資料y ........
# 切割後的X形狀: (1736, 3, 6), 切割後的Y形狀: (1736, 13) ......
# 總共有5208筆切割過的資料X_y, 總共有1736筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-05_346
# 本旅次有幾筆:  718
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (716,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (716,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (716,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (716,)
# 資料形狀: 716
# 切割後的X形狀: (716, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有718筆資料x
# 總共有716筆切割過的資料X, 總共有716筆資料y ........
# 切割後的X形狀: (716, 3, 6), 切割後的Y形狀: (716, 13) ......
# 總共有2148筆切割過的資料X_y, 總共有716筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-28_328
# 本旅次有幾筆:  1156
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1154,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1154,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1154,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1154,)
# 資料形狀: 1154
# 切割後的X形狀: (1154, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1156筆資料x
# 總共有1154筆切割過的資料X, 總共有1154筆資料y ........
# 切割後的X形狀: (1154, 3, 6), 切割後的Y形狀: (1154, 13) ......
# 總共有3462筆切割過的資料X_y, 總共有1154筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-10_216
# 本旅次有幾筆:  1091
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1089,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1089,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1089,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1089,)
# 資料形狀: 1089
# 切割後的X形狀: (1089, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1091筆資料x
# 總共有1089筆切割過的資料X, 總共有1089筆資料y ........
# 切割後的X形狀: (1089, 3, 6), 切割後的Y形狀: (1089, 13) ......
# 總共有3267筆切割過的資料X_y, 總共有1089筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-04_189
# 本旅次有幾筆:  3261
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (3259,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (3259,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (3259,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (3259,)
# 資料形狀: 3259
# 切割後的X形狀: (3259, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有3261筆資料x
# 總共有3259筆切割過的資料X, 總共有3259筆資料y ........
# 切割後的X形狀: (3259, 3, 6), 切割後的Y形狀: (3259, 13) ......
# 總共有9777筆切割過的資料X_y, 總共有3259筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-02_89
# 本旅次有幾筆:  1255
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1253,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1253,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1253,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1253,)
# 資料形狀: 1253
# 切割後的X形狀: (1253, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1255筆資料x
# 總共有1253筆切割過的資料X, 總共有1253筆資料y ........
# 切割後的X形狀: (1253, 3, 6), 切割後的Y形狀: (1253, 13) ......
# 總共有3759筆切割過的資料X_y, 總共有1253筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-28_326
# 本旅次有幾筆:  617
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (615,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (615,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (615,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (615,)
# 資料形狀: 615
# 切割後的X形狀: (615, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有617筆資料x
# 總共有615筆切割過的資料X, 總共有615筆資料y ........
# 切割後的X形狀: (615, 3, 6), 切割後的Y形狀: (615, 13) ......
# 總共有1845筆切割過的資料X_y, 總共有615筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-15_364
# 本旅次有幾筆:  1008
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1006,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1006,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1006,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1006,)
# 資料形狀: 1006
# 切割後的X形狀: (1006, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1008筆資料x
# 總共有1006筆切割過的資料X, 總共有1006筆資料y ........
# 切割後的X形狀: (1006, 3, 6), 切割後的Y形狀: (1006, 13) ......
# 總共有3018筆切割過的資料X_y, 總共有1006筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-10_218
# 本旅次有幾筆:  1163
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (1161,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1161,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (1161,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (1161,)
# 資料形狀: 1161
# 切割後的X形狀: (1161, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有1163筆資料x
# 總共有1161筆切割過的資料X, 總共有1161筆資料y ........
# 切割後的X形狀: (1161, 3, 6), 切割後的Y形狀: (1161, 13) ......
# 總共有3483筆切割過的資料X_y, 總共有1161筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-12_301
# 本旅次有幾筆:  622
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (620,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (620,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (620,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (620,)
# 資料形狀: 620
# 切割後的X形狀: (620, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有622筆資料x
# 總共有620筆切割過的資料X, 總共有620筆資料y ........
# 切割後的X形狀: (620, 3, 6), 切割後的Y形狀: (620, 13) ......
# 總共有1860筆切割過的資料X_y, 總共有620筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-09-13_294
# 本旅次有幾筆:  762
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (760,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (760,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (760,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (760,)
# 資料形狀: 760
# 切割後的X形狀: (760, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有762筆資料x
# 總共有760筆切割過的資料X, 總共有760筆資料y ........
# 切割後的X形狀: (760, 3, 6), 切割後的Y形狀: (760, 13) ......
# 總共有2280筆切割過的資料X_y, 總共有760筆資料y ........
# 下一個旅程 ...
# 旅次名稱:  2020-10-17_282
# 本旅次有幾筆:  901
# --main----go------
# 母體Y的平均、標準差:  11.666715976191353 1.9027595645948943
# 本旅次Y值分類(df_y['level_3_05s'])的shape:  (899,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (899,)
# 母體Y的y軸平均、標準差:  1.8906337921658933 0.854004567910606
# 本旅次Y值分類(df_y['level_3_05s_y'])的shape:  (899,)
# 本旅次Y值分類(df_y['score_3s_all'])的shape:  (899,)
# 資料形狀: 899
# 切割後的X形狀: (899, 3, 6)
# ----------本旅次分數、分類 計算完畢----------------
# ----------本旅次儲存完畢----------------
# 總共有901筆資料x
# 總共有899筆切割過的資料X, 總共有899筆資料y ........
# 切割後的X形狀: (899, 3, 6), 切割後的Y形狀: (899, 13) ......
# 總共有2697筆切割過的資料X_y, 總共有899筆資料y ........
# 下一個旅程 ...
# 本駕駛有84筆>600的資料 .
# 下一個駕駛 ...
#
#
# ---------------------------------------
# 總共有848筆>600的資料.
# 總共有1088204筆x的資料.
# 總共有1086508筆切割窗格過的x資料.
# 1624898860.1393678 1624907841.1239192
# 執行時間：8980.984551 秒
